# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

dt = pd.read_csv('kc_house_data.csv')
dt
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# Floors : 1

ax = sns.barplot(x = "floors", y = "price", data = dt )
ax
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
# waterfront : 1

ax = sns.barplot(x = "waterfront", y = "price", data = dt )
ax
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
# yr_built : 0

ax = sns.barplot(x = 'yr_built' , y = 'price' , data = dt.head(12))
ax.set(xlabel = "yr_built" , ylabel = "price")
# Out:
# [Text(0.5, 0, 'yr_built'), Text(0, 0.5, 'price')]

# %%
# grade : 1

ax = sns.barplot(x = 'grade' , y = 'price' , data = dt)

# %%
# bedrooms : 1

ax = sns.barplot(x = 'bedrooms' , y = 'price' , data = dt)

# %%
# sqft_above : 1

ax = sns.barplot(x = 'sqft_above' , y = 'price' , data = dt)

# %%
# sqft_basement : 1

ax = sns.barplot(x = 'sqft_basement' , y = 'price' , data = dt)

# %%
# view : 1

ax = sns.barplot(x = 'view' , y = 'price' , data = dt)

# %%
# bathrooms : 1

ax = sns.barplot(x = 'bathrooms' , y = 'price' , data = dt)

# %%
# yr_renovated : 0

ax = sns.barplot(x = 'yr_renovated' , y = 'price' , data = dt)

# %%
# lat : 0

ax = sns.barplot(x = 'lat' , y = 'price' , data = dt)

# %%
# long : 0

ax = sns.barplot(x = 'long' , y = 'price' , data = dt)

# %%
#sqft_living15 : 1

ax = sns.barplot(x = 'sqft_living15' , y = 'price' , data = dt)

# %%
# sqft_lot15 : 0

ax = sns.barplot(x = 'sqft_lot15' , y = 'price' , data = dt)

# %%
#sqft_living : 0

ax = sns.barplot(x = 'sqft_living' , y = 'price' , data = dt.head(50))

# %%
# sqft_lot : 0

ax = sns.barplot(x = 'sqft_lot' , y = 'price' , data = dt.head(50))

# %%
# as we can see , the following features 
# (floors , waterfront , grade , bedrooms ,
# sqft_above , sqft_basement , bathrooms , view) 
# got the main influence on the target which is the price
